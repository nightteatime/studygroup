# %% [markdown]
# #  Kaggle Study Group - Predict Sales

# %% [markdown]
# #### Objetivo: prever vendas no mês por produto e loja

# %% [markdown]
# ### 1 - Extração dos Dados

# %%
# import kaggle

# %%
# Data fields

#ID - an Id that represents a (Shop, Item) tuple within the test set
#shop_id - unique identifier of a shop
#item_id - unique identifier of a product
#item_category_id - unique identifier of item category
#item_cnt_day - number of products sold. You are predicting a monthly amount of this measure
#item_price - current price of an item
#date - date in format dd/mm/yyyy
#date_block_num - a consecutive month number, used for convenience. January 2013 is 0, February 2013 is 1,..., October 2015 is 33
#item_name - name of item
#shop_name - name of shop
#item_category_name - name of item category

# %%
#!kaggle competitions download -c competitive-data-science-predict-future-sales -p ~\Desktop\Kaggle_GE
# Out:
# Warning: Looks like you're using an outdated API Version, please consider updating (server 1.3.9.1 / client 1.3.8)
# item_categories.csv: Downloaded 3KB of 3KB to ~\Desktop\Kaggle_GE
#
# items.csv: Downloaded 1MB of 1MB to ~\Desktop\Kaggle_GE
# items.csv: Downloaded 1MB of 1MB to ~\Desktop\Kaggle_GE
#
# shops.csv: Downloaded 3KB of 3KB to ~\Desktop\Kaggle_GE
#
# sample_submission.csv.gz: Downloaded 469KB of 469KB to ~\Desktop\Kaggle_GE
#
# test.csv.gz: Downloaded 1MB of 1MB to ~\Desktop\Kaggle_GE
# test.csv.gz: Downloaded 1MB of 1MB to ~\Desktop\Kaggle_GE
#
# sales_train.csv.gz: Downloaded 1MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 2MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 3MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 4MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 5MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 6MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 7MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 8MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 9MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 10MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 11MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 12MB of 13MB to ~\Desktop\Kaggle_GE
# sales_train.csv.gz: Downloaded 13MB of 13MB to ~\Desktop\Kaggle_GE

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Acessar os arquivos em csv

file_item = os.path.join('..','Kaggle_GE','dataset','items.csv')
file_train = os.path.join('..','Kaggle_GE','dataset','sales_train.csv')
file_test = os.path.join('..','Kaggle_GE','dataset','test.csv')
file_categories = os.path.join('..','Kaggle_GE','dataset','item_categories.csv')
file_shop = os.path.join('..','Kaggle_GE','dataset','shops.csv')

# %%
data_item = pd.read_csv(file_item) #item_name; item_id; item_category_id
data_train = pd.read_csv(file_train) #date; date_block_num; shop_id ;item_id; item_price; item_cnt_day
data_test = pd.read_csv(file_test) #ID; shop_id; item_id
data_categories = pd.read_csv(file_categories)#item_category_name; item_category_id
data_shop= pd.read_csv(file_shop) #shop_name; shop_id

# %% [markdown]
# ### 2 - Análise Explorátoria

# %%
data_train.head(-5)
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# 5        10.01.2013               0       25     2564      349.00
# 6        02.01.2013               0       25     2565      549.00
# 7        04.01.2013               0       25     2572      239.00
# 8        11.01.2013               0       25     2572      299.00
# 9        03.01.2013               0       25     2573      299.00
# 10       03.01.2013               0       25     2574      399.00
# 11       05.01.2013               0       25     2574      399.00
# 12       07.01.2013               0       25     2574      399.00
# 13       08.01.2013               0       25     2574      399.00
# 14       10.01.2013               0       25     2574      399.00
# 15       11.01.2013               0       25     2574      399.00
# 16       13.01.2013               0       25     2574      399.00
# 17       16.01.2013               0       25     2574      399.00
# 18       26.01.2013               0       25     2574      399.00
# 19       27.01.2013               0       25     2574      399.00
# 20       09.01.2013               0       25     2593      279.00
# 21       16.01.2013               0       25     2604      299.00
# 22       27.01.2013               0       25     2604      299.00
# 23       27.01.2013               0       25     2607      279.00
# 24       29.01.2013               0       25     2607      279.00
# 25       27.01.2013               0       25     2609     1699.00
# 26       06.01.2013               0       25     2548     1708.95
# 27       26.01.2013               0       25     2611      299.00
# 28       02.01.2013               0       25     2546      299.00
# 29       06.01.2013               0       25     2515     1649.00
# ...             ...             ...      ...      ...         ...
# 2935814  05.10.2015              33       25     7780      248.00
# 2935815  24.10.2015              33       25     7231      999.00
# 2935816  19.10.2015              33       25     7780      248.00
# 2935817  23.10.2015              33       25     7780      248.00
# 2935818  31.10.2015              33       25     7780      198.00
# 2935819  16.10.2015              33       25     7789     1799.00
# 2935820  22.10.2015              33       25     7790      799.00
# 2935821  22.10.2015              33       25     7791      899.50
# 2935822  17.10.2015              33       25     7632     2310.00
# 2935823  26.10.2015              33       25     7487      299.00
# 2935824  14.10.2015              33       25     7029      999.00
# 2935825  23.10.2015              33       25     7460      299.00
# 2935826  04.10.2015              33       25     7233      599.00
# 2935827  18.10.2015              33       25     7308      349.00
# 2935828  21.10.2015              33       25     7233      479.00
# 2935829  03.10.2015              33       25     7233      599.00
# 2935830  11.10.2015              33       25     7286      299.00
# 2935831  22.10.2015              33       25     7187      299.00
# 2935832  26.10.2015              33       25     7484      299.00
# 2935833  22.10.2015              33       25     7308      349.00
# 2935834  29.10.2015              33       25     7235      298.00
# 2935835  18.10.2015              33       25     7327      349.00
# 2935836  22.10.2015              33       25     7327      349.00
# 2935837  24.10.2015              33       25     7328      249.00
# 2935838  17.10.2015              33       25     7338      349.00
# 2935839  24.10.2015              33       25     7315      399.00
# 2935840  31.10.2015              33       25     7409      299.00
# 2935841  11.10.2015              33       25     7393      349.00
# 2935842  10.10.2015              33       25     7384      749.00
# 2935843  09.10.2015              33       25     7409      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# 5                 1.0
# 6                 1.0
# 7                 1.0
# 8                 1.0
# 9                 3.0
# 10                2.0
# 11                1.0
# 12                1.0
# 13                2.0
# 14                1.0
# 15                2.0
# 16                1.0
# 17                1.0
# 18                1.0
# 19                1.0
# 20                1.0
# 21                1.0
# 22                1.0
# 23                1.0
# 24                1.0
# 25                1.0
# 26                1.0
# 27                1.0
# 28                1.0
# 29                1.0
# ...               ...
# 2935814           1.0
# 2935815           1.0
# 2935816           1.0
# 2935817           2.0
# 2935818           1.0
# 2935819           1.0
# 2935820           1.0
# 2935821           1.0
# 2935822           1.0
# 2935823           1.0
# 2935824           1.0
# 2935825           1.0
# 2935826           1.0
# 2935827           1.0
# 2935828           1.0
# 2935829           1.0
# 2935830           1.0
# 2935831           1.0
# 2935832           1.0
# 2935833           1.0
# 2935834           1.0
# 2935835           1.0
# 2935836           1.0
# 2935837           1.0
# 2935838           1.0
# 2935839           1.0
# 2935840           1.0
# 2935841           1.0
# 2935842           1.0
# 2935843           1.0
#
# [2935844 rows x 6 columns]

# %%
# Temos vários valores com (-1)
data_train.item_cnt_day.value_counts()
# Out:
#  1.0      2629372
#  2.0       194201
#  3.0        47350
#  4.0        19685
#  5.0        10474
# -1.0         7252
#  6.0         6338
#  7.0         4057
#  8.0         2903
#  9.0         2177
#  10.0        1820
#  11.0        1263
#  12.0        1083
#  13.0         918
#  14.0         716
#  15.0         638
#  16.0         544
#  17.0         438
#  18.0         391
#  20.0         364
#  19.0         347
#  21.0         290
#  22.0         242
#  24.0         204
#  23.0         198
#  25.0         180
#  26.0         176
#  30.0         147
#  28.0         131
#  27.0         130
#            ...
#  95.0           1
#  96.0           1
#  102.0          1
#  105.0          1
#  109.0          1
#  112.0          1
#  113.0          1
#  118.0          1
#  128.0          1
#  129.0          1
#  131.0          1
#  132.0          1
#  135.0          1
#  146.0          1
#  200.0          1
#  147.0          1
#  149.0          1
#  153.0          1
#  154.0          1
#  156.0          1
#  157.0          1
#  504.0          1
#  163.0          1
#  164.0          1
#  167.0          1
#  179.0          1
#  187.0          1
#  194.0          1
#  195.0          1
#  508.0          1
# Name: item_cnt_day, Length: 198, dtype: int64

# %%
data_train.describe() # porque o minímo e máximo estão dando números quebrados?
# Out:
#        date_block_num       shop_id       item_id    item_price  item_cnt_day
# count    2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06  2.935849e+06
# mean     1.456991e+01  3.300173e+01  1.019723e+04  8.908532e+02  1.242641e+00
# std      9.422988e+00  1.622697e+01  6.324297e+03  1.729800e+03  2.618834e+00
# min      0.000000e+00  0.000000e+00  0.000000e+00 -1.000000e+00 -2.200000e+01
# 25%      7.000000e+00  2.200000e+01  4.476000e+03  2.490000e+02  1.000000e+00
# 50%      1.400000e+01  3.100000e+01  9.343000e+03  3.990000e+02  1.000000e+00
# 75%      2.300000e+01  4.700000e+01  1.568400e+04  9.990000e+02  1.000000e+00
# max      3.300000e+01  5.900000e+01  2.216900e+04  3.079800e+05  2.169000e+03

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
data_shop.head()
# Out:
#                         shop_name  shop_id
# 0   !Якутск Орджоникидзе, 56 фран        0
# 1   !Якутск ТЦ "Центральный" фран        1
# 2                Адыгея ТЦ "Мега"        2
# 3  Балашиха ТРК "Октябрь-Киномир"        3
# 4        Волжский ТЦ "Волга Молл"        4

# %%
data_categories.head()
# Out:
#         item_category_name  item_category_id
# 0  PC - Гарнитуры/Наушники                 0
# 1         Аксессуары - PS2                 1
# 2         Аксессуары - PS3                 2
# 3         Аксессуары - PS4                 3
# 4         Аксессуары - PSP                 4

# %%
data_train.date_block_num.value_counts()
# Out:
# 11    143246
# 23    130786
# 2     121347
# 0     115690
# 1     108613
# 7     104772
# 6     100548
# 5     100403
# 12     99349
# 10     96736
# 8      96137
# 9      94202
# 3      94109
# 14     92733
# 4      91759
# 13     89830
# 24     88522
# 19     86614
# 22     86428
# 17     82408
# 21     79361
# 18     78760
# 16     78529
# 15     77906
# 20     73157
# 25     71808
# 26     69977
# 31     57029
# 27     56274
# 30     55549
# 29     54617
# 28     54548
# 33     53514
# 32     50588
# Name: date_block_num, dtype: int64

# %% [markdown]
# #### Precisamos agrupar os dias em meses

# %%
data_train_2 = data_train

# %%
data_train_2.head()
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0

# %%
# Agrupar pelo código date_block_num
data_train_3 = data_train_2.groupby(by='date_block_num',as_index=False).sum()

# %% [markdown]
# #### tentar plotar gráficos

# %%
data_train_3
# Out:
#     date_block_num  shop_id     item_id    item_price  item_cnt_day
# 0                0  3417068  1183971787  8.221187e+07      131479.0
# 1                1  3111582  1076043980  7.558019e+07      128090.0
# 2                2  4016457  1220911622  8.429831e+07      147142.0
# 3                3  3164978   971345965  6.151282e+07      107190.0
# 4                4  3093999   950372988  5.727413e+07      106970.0
# 5                5  3364700  1047351238  6.334361e+07      125381.0
# 6                6  3376156  1067060380  6.219681e+07      116966.0
# 7                7  3510787  1065970958  6.543817e+07      125291.0
# 8                8  3208314   957871641  7.270157e+07      133332.0
# 9                9  3101078   966066011  7.391497e+07      127541.0
# 10              10  3229598   974859705  7.960888e+07      130009.0
# 11              11  4747485  1424369716  1.431799e+08      183342.0
# 12              12  3317287   996727749  8.572518e+07      116899.0
# 13              13  2982160   866201555  7.783305e+07      109687.0
# 14              14  3117514   931084282  8.355875e+07      115297.0
# 15              15  2608134   811885179  6.638839e+07       96556.0
# 16              16  2649821   800026877  6.753802e+07       97790.0
# 17              17  2774465   831994894  7.198654e+07       97429.0
# 18              18  2671321   799658913  6.671338e+07       91280.0
# 19              19  2948523   879409093  7.681620e+07      102721.0
# 20              20  2462241   739754807  7.735488e+07       99208.0
# 21              21  2621774   817071654  8.488921e+07      107422.0
# 22              22  2899400   853857509  1.053448e+08      117845.0
# 23              23  4339498  1330492992  1.794057e+08      168755.0
# 24              24  2991797   906227293  1.005736e+08      110971.0
# 25              25  2405142   753397832  7.255950e+07       84198.0
# 26              26  2365258   737212776  7.145842e+07       82014.0
# 27              27  1827819   589741486  5.897193e+07       77827.0
# 28              28  1764840   566095394  5.874271e+07       72295.0
# 29              29  1763694   568759443  5.573324e+07       64114.0
# 30              30  1823463   589694328  5.370635e+07       63187.0
# 31              31  1883430   579633738  5.425592e+07       66079.0
# 32              32  1638284   504444591  5.906161e+07       72843.0
# 33              33  1690024   577950482  6.553190e+07       71056.0

# %%
sns.barplot(x="date_block_num", y='item_cnt_day',data=data_train_3)
